# %% [markdown]
# ## Beautiful Soup. So Beatiful

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import folium # map rendering library

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

from bs4 import BeautifulSoup

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
soup = BeautifulSoup(website_url,'html.parser')
#print(soup.prettify())

# %%
My_table = soup.find('table')
#My_table

# %%
#print(My_table.tr.text)

# %%
import re
headers="Postcode,Borough,Neighbourhood"

table1="\n"
for tr in My_table.find_all('tr'):
    for tds in tr.find_all('td'):
            r1=re.findall("[(^)[\]{}].+[()[\]{}]",tds.text)
            r1plus=re.findall("[()[\]{}(^)].+",tds.text)
            if len(r1)>=1:
                r1f=str(r1[0][1:-1])
                r1f=r1f.replace(",","/",)
                r1plus=str(r1plus[0][1:-1])
                r0=tds.text[4:-4]
                r0f=r0[:-len(r1plus)]
            else:
                r1f="Not assigned"
                r0f=tds.text[4:-2]
            row1=tds.text[1:4]+","+r0f+','+r1f+'\n'
            table1=table1+row1[:]
#print(table1)

# %%
file=open("toronto.csv","wb")
file.write(bytes(headers,encoding="ascii",errors="ignore"))
file.write(bytes(table1,encoding="ascii",errors="ignore"))
# Out:
# 7373

# %%
df = pd.read_csv('toronto.csv')
df.columns=["Postalcode","Borough","Neighbourhood"]

# %%
indexNames = df[ df['Borough'] =='Not assigned'].index
df.drop(indexNames , inplace=True)

df.loc[df['Neighbourhood'] =='Not assigned' , 'Neighbourhood'] = df['Borough']

df['Neighbourhood']=df['Neighbourhood'].replace(regex=' /', value=',')
df['Neighbourhood']=df['Neighbourhood'].replace(regex='/ ', value=', ')

# %%
df.shape
# Out:
# (103, 3)

# %%
df_lon_lat = pd.read_csv('Toronto_long_lat_data.csv')
df_lon_lat.columns=['Postalcode','Latitude','Longitude']

# %% [markdown]
# ## Explore and cluster the neighborhoods in Toronto¶

# %%
Toronto_df = pd.merge(df,
                 df_lon_lat[['Postalcode','Latitude', 'Longitude']],
                 on='Postalcode')
Toronto_df
# Out:
#     Postalcode                                            Borough  \
# 0          M3A                                         North York
# 1          M4A                                         North York
# 2          M5A                                   Downtown Toronto
# 3          M6A                                         North York
# 4          M7A       Queen's Park / Ontario Provincial Government
# 5          M9A                                          Etobicoke
# 6          M1B                                        Scarborough
# 7          M3B                                         North York
# 8          M4B                                          East York
# 9          M5B                                   Downtown Toronto
# 10         M6B                                         North York
# 11         M9B                                          Etobicoke
# 12         M1C                                        Scarborough
# 13         M3C                                         North York
# 14         M4C                                          East York
# 15         M5C                                   Downtown Toronto
# 16         M6C                                               York
# 17         M9C                                          Etobicoke
# 18         M1E                                        Scarborough
# 19         M4E                                       East Toronto
# 20         M5E                                   Downtown Toronto
# 21         M6E                                               York
# 22         M1G                                        Scarborough
# 23         M4G                                          East York
# 24         M5G                                   Downtown Toronto
# 25         M6G                                   Downtown Toronto
# 26         M1H                                        Scarborough
# 27         M2H                                         North York
# 28         M3H                                         North York
# 29         M4H                                          East York
# 30         M5H                                   Downtown Toronto
# 31         M6H                                       West Toronto
# 32         M1J                                        Scarborough
# 33         M2J                                         North York
# 34         M3J                                         North York
# 35         M4J                              East YorkEast Toronto
# 36         M5J                                   Downtown Toronto
# 37         M6J                                       West Toronto
# 38         M1K                                        Scarborough
# 39         M2K                                         North York
# 40         M3K                                         North York
# 41         M4K                                       East Toronto
# 42         M5K                                   Downtown Toronto
# 43         M6K                                       West Toronto
# 44         M1L                                        Scarborough
# 45         M2L                                         North York
# 46         M3L                                         North York
# 47         M4L                                       East Toronto
# 48         M5L                                   Downtown Toronto
# 49         M6L                                         North York
# 50         M9L                                         North York
# 51         M1M                                        Scarborough
# 52         M2M                                         North York
# 53         M3M                                         North York
# 54         M4M                                       East Toronto
# 55         M5M                                         North York
# 56         M6M                                               York
# 57         M9M                                         North York
# 58         M1N                                        Scarborough
# 59         M2N                                         North York
# 60         M3N                                         North York
# 61         M4N                                    Central Toronto
# 62         M5N                                    Central Toronto
# 63         M6N                                               York
# 64         M9N                                               York
# 65         M1P                                        Scarborough
# 66         M2P                                         North York
# 67         M4P                                    Central Toronto
# 68         M5P                                    Central Toronto
# 69         M6P                                       West Toronto
# 70         M9P                                          Etobicoke
# 71         M1R                                        Scarborough
# 72         M2R                                         North York
# 73         M4R                                    Central Toronto
# 74         M5R                                    Central Toronto
# 75         M6R                                       West Toronto
# 76         M7R   MississaugaCanada Post Gateway Processing Centre
# 77         M9R                                          Etobicoke
# 78         M1S                                        Scarborough
# 79         M4S                                    Central Toronto
# 80         M5S                                   Downtown Toronto
# 81         M6S                                       West Toronto
# 82         M1T                                        Scarborough
# 83         M4T                                    Central Toronto
# 84         M5T                                   Downtown Toronto
# 85         M1V                                        Scarborough
# 86         M4V                                    Central Toronto
# 87         M5V                                   Downtown Toronto
# 88         M8V                                          Etobicoke
# 89         M9V                                          Etobicoke
# 90         M1W                                        Scarborough
# 91         M4W                                   Downtown Toronto
# 92         M5W     Downtown TorontoStn A PO Boxes25 The Esplanade
# 93         M8W                                          Etobicoke
# 94         M9W                                 EtobicokeNorthwest
# 95         M1X                                        Scarborough
# 96         M4X                                   Downtown Toronto
# 97         M5X                                   Downtown Toronto
# 98         M8X                                          Etobicoke
# 99         M4Y                                   Downtown Toronto
# 100        M7Y  East TorontoBusiness reply mail Processing Cen...
# 101        M8Y                                          Etobicoke
# 102        M8Z                                          Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 7                                            Don Mills  43.745906 -79.352188
# 8                      Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                             Garden District, Ryerson  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 12              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 13                     Don Mills)South(Flemingdon Park  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# 30                            Richmond, Adelaide, King  43.650571 -79.384568
# 31                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 32                                 Scarborough Village  43.744734 -79.239476
# 33                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 34                     Northwood Park, York University  43.767980 -79.487262
# 35                                  The Danforth  East  43.685347 -79.338106
# 36   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 38         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 39                                     Bayview Village  43.786947 -79.385975
# 40                        Downsview)East  (CFB Toronto  43.737473 -79.464763
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 43        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 44                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 45                            York Mills, Silver Hills  43.757490 -79.374714
# 46                                           Downsview  43.739015 -79.506944
# 47                      India Bazaar, The Beaches West  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 49            North Park, Maple Leaf Park, Upwood Park  43.713756 -79.490074
# 50                                       Humber Summit  43.756303 -79.565963
# 51     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 52                             Willowdale, Newtonbrook  43.789053 -79.408493
# 53                                           Downsview  43.728496 -79.495697
# 54                                     Studio District  43.659526 -79.340923
# 55                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 56    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 57                                    Humberlea, Emery  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 59                                          Willowdale  43.770120 -79.408493
# 60                                           Downsview  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 63                       Runnymede, The Junction North  43.673185 -79.487262
# 64                                              Weston  43.706876 -79.518188
# 65   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 66                                     York Mills West  43.752758 -79.400049
# 67                                    Davisville North  43.712751 -79.390197
# 68                            Forest Hill North & West  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 70                                           Westmount  43.696319 -79.532242
# 71                                   Wexford, Maryvale  43.750072 -79.295849
# 72                                          Willowdale  43.782736 -79.442259
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76                                      Enclave of L4W  43.636966 -79.615819
# 77   Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 85   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 86   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 87   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89   South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 90                       Steeles West, L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                                      Enclave of M5E  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94   Clairville, Humberwood, Woodbine Downs, West H...  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100                                     Enclave of M4L  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999

# %%
Toronto_df.to_csv(r'df_final.csv')

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude_toronto = location.latitude
longitude_toronto = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_toronto, longitude_toronto))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=10)

# add markers to map
for lat, lng, borough, Neighbourhood in zip(Toronto_df['Latitude'], Toronto_df['Longitude'], Toronto_df['Borough'], Toronto_df['Neighbourhood']):
    label = '{}, {}'.format(Neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Credentials
CLIENT_ID = 'HD1NAYFDOU5MXUS5EYLRNKNHDRV24LQ5PMVJ0QK1LLQNDD5P' # your Foursquare ID
CLIENT_SECRET = 'S33QQLOFTKNBC3KKOQKHBDJLR0XRICWMH1RB1T1QMU3JEGZ0' # your Foursquare Secret
VERSION = '20191225' # Foursquare API version

# %%
# defining radius and limit of venues to get
radius=500
LIMIT=100

# %%
#import requests
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=Toronto_df['Neighbourhood'],
                                   latitudes=Toronto_df['Latitude'],
                                   longitudes=Toronto_df['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Queen's Park, Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills)South(Flemingdon Park
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview)East  (CFB Toronto
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale
# Downsview
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Enclave of L4W
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Enclave of M5E
# Alderwood, Long Branch
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Enclave of M4L
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix = '', prefix_sep = "")
# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 
# add neighbourhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# dataframe with top 10 venues for each neighborhood

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.head()
# Out:
#                                      Neighbourhood      1st Most Common Venue  \
# 0                                        Agincourt  Latin American Restaurant
# 1                           Alderwood, Long Branch                Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                       Bank
# 3                                  Bayview Village                       Café
# 4                Bedford Park, Lawrence Manor East         Italian Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Breakfast Spot        Clothing Store                Lounge
# 1                   Gym              Pharmacy        Sandwich Place
# 2           Coffee Shop           Supermarket      Sushi Restaurant
# 3                  Bank    Chinese Restaurant   Japanese Restaurant
# 4           Coffee Shop        Sandwich Place            Restaurant
#
#   5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 0          Skating Rink     Electronics Store  Eastern European Restaurant
# 1          Skating Rink                  Pool                          Pub
# 2        Ice Cream Shop         Deli / Bodega    Middle Eastern Restaurant
# 3      Doner Restaurant                 Diner               Discount Store
# 4                   Pub                  Café             Sushi Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0   Empanada Restaurant   Dumpling Restaurant           Dessert Shop
# 1           Coffee Shop            Comic Shop           Dance Studio
# 2            Restaurant           Pizza Place    Fried Chicken Joint
# 3   Distribution Center               Dog Run             Donut Shop
# 4        Ice Cream Shop     Indian Restaurant   Fast Food Restaurant

# %% [markdown]
# ## Cluster Neighbourhoods : K-means

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
# kmeans.labels_

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster_Labels', kmeans.labels_)

toronto_merged = Toronto_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postalcode                                       Borough  \
# 0        M3A                                    North York
# 1        M4A                                    North York
# 2        M5A                              Downtown Toronto
# 3        M6A                                    North York
# 4        M7A  Queen's Park / Ontario Provincial Government
#
#                                  Neighbourhood   Latitude  Longitude  \
# 0                                    Parkwoods  43.753259 -79.329656
# 1                             Victoria Village  43.725882 -79.315572
# 2                    Regent Park, Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park, Ontario Provincial Government  43.662301 -79.389494
#
#    Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0             0.0                  Park     Food & Drink Shop
# 1             3.0          Hockey Arena           Coffee Shop
# 2             3.0           Coffee Shop                Bakery
# 3             3.0        Clothing Store     Accessories Store
# 4             3.0           Coffee Shop                  Park
#
#         3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0                 Yoga Studio                Dog Run          Dessert Shop
# 1  Financial or Legal Service  Portuguese Restaurant           Yoga Studio
# 2                         Pub                   Park               Theater
# 3      Furniture / Home Store            Coffee Shop    Miscellaneous Shop
# 4                 Yoga Studio               Creperie            Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    Dim Sum Restaurant                 Diner        Discount Store
# 1          Dessert Shop    Dim Sum Restaurant                 Diner
# 2            Restaurant                  Café    Mexican Restaurant
# 3            Shoe Store              Boutique           Event Space
# 4             Nightclub    Mexican Restaurant             Juice Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 0    Distribution Center       Doner Restaurant
# 1         Discount Store    Distribution Center
# 2            Event Space         Chocolate Shop
# 3  Vietnamese Restaurant              Gift Shop
# 4     Italian Restaurant             Hobby Shop

# %%
#no data available for some neighbourhood : drop row
toronto_merged=toronto_merged.dropna()
toronto_merged['Cluster_Labels'] = toronto_merged.Cluster_Labels.astype(int)

# create map
map_clusters = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster_Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                   Borough  Cluster_Labels 1st Most Common Venue  \
# 0              North York               0                  Park
# 10             North York               0                  Park
# 21                   York               0                  Park
# 32            Scarborough               0            Playground
# 35  East YorkEast Toronto               0                  Park
# 40             North York               0                  Park
# 45             North York               0             Cafeteria
# 49             North York               0                  Park
# 61        Central Toronto               0  Gym / Fitness Center
# 66             North York               0                  Park
# 68        Central Toronto               0                  Park
# 77              Etobicoke               0                  Park
# 83        Central Toronto               0                   Gym
# 85            Scarborough               0                  Park
# 91       Downtown Toronto               0                  Park
# 98              Etobicoke               0                 River
#
#          2nd Most Common Venue       3rd Most Common Venue  \
# 0            Food & Drink Shop                 Yoga Studio
# 10                         Pub            Sushi Restaurant
# 21               Women's Store                      Market
# 32  Construction & Landscaping                 Yoga Studio
# 35           Convenience Store               Metro Station
# 40                     Airport                 Yoga Studio
# 45            Doner Restaurant                Dessert Shop
# 49                      Bakery  Construction & Landscaping
# 61                        Park                 Swim School
# 66                        Bank           Convenience Store
# 68               Jewelry Store            Sushi Restaurant
# 77                 Pizza Place              Sandwich Place
# 83                        Park                Tennis Court
# 85                      Bakery                 Coffee Shop
# 91                  Playground                       Trail
# 98                        Park                     Dog Run
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                Dog Run          Dessert Shop    Dim Sum Restaurant
# 10   Japanese Restaurant           Yoga Studio   Distribution Center
# 21           Yoga Studio      Doner Restaurant    Dim Sum Restaurant
# 32      Doner Restaurant          Dessert Shop    Dim Sum Restaurant
# 35               Dog Run          Dessert Shop    Dim Sum Restaurant
# 40            Donut Shop    Dim Sum Restaurant                 Diner
# 45    Dim Sum Restaurant                 Diner        Discount Store
# 49           Yoga Studio            Donut Shop                 Diner
# 61              Bus Line           Yoga Studio               Dog Run
# 66           Yoga Studio            Donut Shop                 Diner
# 68                 Trail           Yoga Studio               Dog Run
# 77           Yoga Studio               Dog Run          Dessert Shop
# 83            Playground   Distribution Center      Department Store
# 85            Playground           Yoga Studio               Dog Run
# 91           Yoga Studio               Dog Run      Department Store
# 98      Department Store          Dessert Shop    Dim Sum Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                  Diner        Discount Store   Distribution Center
# 10          Dessert Shop    Dim Sum Restaurant                 Diner
# 21                 Diner        Discount Store   Distribution Center
# 32                 Diner        Discount Store   Distribution Center
# 35                 Diner        Discount Store   Distribution Center
# 40        Discount Store   Distribution Center               Dog Run
# 45   Distribution Center               Dog Run            Donut Shop
# 49        Discount Store   Distribution Center               Dog Run
# 61    Dim Sum Restaurant                 Diner        Discount Store
# 66        Discount Store   Distribution Center               Dog Run
# 68          Dessert Shop    Dim Sum Restaurant                 Diner
# 77    Dim Sum Restaurant                 Diner        Discount Store
# 83          Dessert Shop    Dim Sum Restaurant                 Diner
# 85          Dessert Shop    Dim Sum Restaurant                 Diner
# 91          Dessert Shop    Dim Sum Restaurant                 Diner
# 98                 Diner        Discount Store   Distribution Center
#
#    10th Most Common Venue
# 0        Doner Restaurant
# 10         Discount Store
# 21                Dog Run
# 32                Dog Run
# 35            Yoga Studio
# 40       Doner Restaurant
# 45     College Rec Center
# 49       Doner Restaurant
# 61    Distribution Center
# 66       Doner Restaurant
# 68         Discount Store
# 77    Distribution Center
# 83         Discount Store
# 85         Discount Store
# 91         Discount Store
# 98            Yoga Studio

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster_Labels 1st Most Common Venue  \
# 62  Central Toronto               1                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 62           Yoga Studio               Dog Run          Dessert Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 62    Dim Sum Restaurant                 Diner        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 62   Distribution Center      Doner Restaurant          Deli / Bodega

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 12  Scarborough               2                   Bar           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12      Doner Restaurant    Dim Sum Restaurant                 Diner
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 12        Discount Store   Distribution Center               Dog Run
#
#    9th Most Common Venue 10th Most Common Venue
# 12            Donut Shop     Falafel Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                                Borough  Cluster_Labels  \
# 1                                           North York               3
# 2                                     Downtown Toronto               3
# 3                                           North York               3
# 4         Queen's Park / Ontario Provincial Government               3
# 6                                          Scarborough               3
# 7                                           North York               3
# 8                                            East York               3
# 9                                     Downtown Toronto               3
# 13                                          North York               3
# 14                                           East York               3
# 15                                    Downtown Toronto               3
# 16                                                York               3
# 17                                           Etobicoke               3
# 18                                         Scarborough               3
# 19                                        East Toronto               3
# 20                                    Downtown Toronto               3
# 22                                         Scarborough               3
# 23                                           East York               3
# 24                                    Downtown Toronto               3
# 25                                    Downtown Toronto               3
# 26                                         Scarborough               3
# 27                                          North York               3
# 28                                          North York               3
# 29                                           East York               3
# 30                                    Downtown Toronto               3
# 31                                        West Toronto               3
# 33                                          North York               3
# 34                                          North York               3
# 36                                    Downtown Toronto               3
# 37                                        West Toronto               3
# 38                                         Scarborough               3
# 39                                          North York               3
# 41                                        East Toronto               3
# 42                                    Downtown Toronto               3
# 43                                        West Toronto               3
# 44                                         Scarborough               3
# 46                                          North York               3
# 47                                        East Toronto               3
# 48                                    Downtown Toronto               3
# 50                                          North York               3
# 51                                         Scarborough               3
# 53                                          North York               3
# 54                                        East Toronto               3
# 55                                          North York               3
# 56                                                York               3
# 57                                          North York               3
# 58                                         Scarborough               3
# 59                                          North York               3
# 60                                          North York               3
# 63                                                York               3
# 64                                                York               3
# 65                                         Scarborough               3
# 67                                     Central Toronto               3
# 69                                        West Toronto               3
# 70                                           Etobicoke               3
# 71                                         Scarborough               3
# 72                                          North York               3
# 73                                     Central Toronto               3
# 74                                     Central Toronto               3
# 75                                        West Toronto               3
# 76    MississaugaCanada Post Gateway Processing Centre               3
# 78                                         Scarborough               3
# 79                                     Central Toronto               3
# 80                                    Downtown Toronto               3
# 81                                        West Toronto               3
# 82                                         Scarborough               3
# 84                                    Downtown Toronto               3
# 86                                     Central Toronto               3
# 87                                    Downtown Toronto               3
# 88                                           Etobicoke               3
# 89                                           Etobicoke               3
# 90                                         Scarborough               3
# 92      Downtown TorontoStn A PO Boxes25 The Esplanade               3
# 93                                           Etobicoke               3
# 94                                  EtobicokeNorthwest               3
# 96                                    Downtown Toronto               3
# 97                                    Downtown Toronto               3
# 99                                    Downtown Toronto               3
# 100  East TorontoBusiness reply mail Processing Cen...               3
# 101                                          Etobicoke               3
# 102                                          Etobicoke               3
#
#          1st Most Common Venue  2nd Most Common Venue  \
# 1                 Hockey Arena            Coffee Shop
# 2                  Coffee Shop                 Bakery
# 3               Clothing Store      Accessories Store
# 4                  Coffee Shop                   Park
# 6         Fast Food Restaurant            Yoga Studio
# 7          Japanese Restaurant   Gym / Fitness Center
# 8                  Pizza Place              Gastropub
# 9                  Coffee Shop         Clothing Store
# 13                         Gym            Coffee Shop
# 14                Skating Rink            Curling Ice
# 15                 Coffee Shop             Restaurant
# 16                       Field           Hockey Arena
# 17           Convenience Store         Shopping Plaza
# 18           Electronics Store     Mexican Restaurant
# 19                       Trail                    Pub
# 20                 Coffee Shop           Cocktail Bar
# 22                 Coffee Shop           Soccer Field
# 23      Furniture / Home Store            Coffee Shop
# 24                 Coffee Shop     Italian Restaurant
# 25               Grocery Store                   Café
# 26                 Gas Station                 Bakery
# 27                     Dog Run            Golf Course
# 28                        Bank            Coffee Shop
# 29           Indian Restaurant            Yoga Studio
# 30                 Coffee Shop             Restaurant
# 31                      Bakery            Pizza Place
# 33              Clothing Store            Coffee Shop
# 34              Massage Studio          Metro Station
# 36                 Coffee Shop               Aquarium
# 37                         Bar            Coffee Shop
# 38              Discount Store            Coffee Shop
# 39                        Café                   Bank
# 41            Greek Restaurant            Coffee Shop
# 42                 Coffee Shop                  Hotel
# 43              Breakfast Spot                   Café
# 44                      Bakery               Bus Line
# 46               Grocery Store                   Bank
# 47                         Gym                    Pub
# 48                 Coffee Shop                   Café
# 50         Empanada Restaurant          Shopping Mall
# 51                Skating Rink          Movie Theater
# 53               Grocery Store                   Bank
# 54                        Café            Coffee Shop
# 55          Italian Restaurant            Coffee Shop
# 56                Skating Rink   Fast Food Restaurant
# 57      Furniture / Home Store         Baseball Field
# 58             College Stadium  General Entertainment
# 59            Ramen Restaurant            Pizza Place
# 60               Grocery Store                   Bank
# 63               Grocery Store               Bus Line
# 64           Convenience Store             Donut Shop
# 65           Indian Restaurant              Pet Store
# 67                         Gym   Gym / Fitness Center
# 69                         Bar                   Café
# 70                 Pizza Place         Sandwich Place
# 71                  Smoke Shop            Auto Garage
# 72            Ramen Restaurant            Pizza Place
# 73                 Coffee Shop         Clothing Store
# 74              Sandwich Place                   Café
# 75                   Gift Shop             Restaurant
# 76                       Hotel           Intersection
# 78   Latin American Restaurant         Breakfast Spot
# 79                Dessert Shop         Sandwich Place
# 80                        Café                 Bakery
# 81                 Pizza Place                   Café
# 82                 Pizza Place          Shopping Mall
# 84                         Bar                   Café
# 86                 Coffee Shop                    Pub
# 87              Airport Lounge        Airport Service
# 88                         Gym    American Restaurant
# 89               Grocery Store             Beer Store
# 90          Chinese Restaurant   Fast Food Restaurant
# 92                 Coffee Shop                   Café
# 93                 Pizza Place                    Gym
# 94         Rental Car Location              Drugstore
# 96                 Coffee Shop                 Bakery
# 97                 Coffee Shop                   Café
# 99                 Coffee Shop    Japanese Restaurant
# 100                 Restaurant          Auto Workshop
# 101                  Locksmith         Baseball Field
# 102                        Gym                 Bakery
#
#           3rd Most Common Venue          4th Most Common Venue  \
# 1    Financial or Legal Service          Portuguese Restaurant
# 2                           Pub                           Park
# 3        Furniture / Home Store                    Coffee Shop
# 4                   Yoga Studio                       Creperie
# 6              Doner Restaurant                   Dessert Shop
# 7          Caribbean Restaurant                 Baseball Field
# 8                          Café                   Intersection
# 9           Japanese Restaurant                           Café
# 13                   Restaurant               Asian Restaurant
# 14                         Park                     Beer Store
# 15                         Café                          Hotel
# 16                   Playground                          Trail
# 17                         Café                   Liquor Store
# 18                          Spa                 Medical Center
# 19                 Neighborhood              Health Food Store
# 20           Seafood Restaurant                       Beer Bar
# 22            Korean Restaurant                     Donut Shop
# 23          Sporting Goods Shop                   Burger Joint
# 24                 Burger Joint                 Ice Cream Shop
# 25                         Park                      Nightclub
# 26          Fried Chicken Joint           Caribbean Restaurant
# 27     Mediterranean Restaurant                           Pool
# 28                  Supermarket               Sushi Restaurant
# 29                  Supermarket                           Bank
# 30              Thai Restaurant                           Café
# 31                     Pharmacy                           Pool
# 33         Fast Food Restaurant                         Bakery
# 34         Caribbean Restaurant                    Coffee Shop
# 36                         Café                          Hotel
# 37             Asian Restaurant                     Restaurant
# 38            Convenience Store               Department Store
# 39           Chinese Restaurant            Japanese Restaurant
# 41           Italian Restaurant                 Ice Cream Shop
# 42                         Café                     Restaurant
# 43                  Coffee Shop                      Pet Store
# 44               Ice Cream Shop                  Metro Station
# 46           Athletics & Sports                     Food Truck
# 47               Sandwich Place                     Board Shop
# 48                   Restaurant                          Hotel
# 50                  Pizza Place                        Dog Run
# 51                        Motel            American Restaurant
# 53           Athletics & Sports                     Food Truck
# 54          American Restaurant                         Bakery
# 55               Sandwich Place                     Restaurant
# 56               Discount Store                 Sandwich Place
# 57                  Yoga Studio               Department Store
# 58                 Skating Rink                           Café
# 59                  Coffee Shop                  Grocery Store
# 60           Athletics & Sports                     Food Truck
# 63                      Brewery              Convenience Store
# 64           Dim Sum Restaurant                          Diner
# 65        Vietnamese Restaurant             Chinese Restaurant
# 67                         Park                 Breakfast Spot
# 69           Mexican Restaurant                Thai Restaurant
# 70                  Coffee Shop                 Discount Store
# 71                Shopping Mall                 Breakfast Spot
# 72                  Coffee Shop                  Grocery Store
# 73          Sporting Goods Shop           Gym / Fitness Center
# 74                  Coffee Shop                       Pharmacy
# 75                      Dog Run                 Breakfast Spot
# 76                  Coffee Shop            American Restaurant
# 78               Clothing Store                         Lounge
# 79                  Pizza Place                            Gym
# 80                   Restaurant                            Bar
# 81                  Coffee Shop               Sushi Restaurant
# 82                     Pharmacy                   Intersection
# 84        Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 86                 Liquor Store                   Burger Joint
# 87             Sculpture Garden               Airport Terminal
# 88                   Restaurant               Business Service
# 89               Sandwich Place            Fried Chicken Joint
# 90                  Pizza Place                    Coffee Shop
# 92           Seafood Restaurant                     Restaurant
# 93                     Pharmacy                 Sandwich Place
# 94                      Dog Run               Department Store
# 96                   Restaurant             Italian Restaurant
# 97                   Restaurant                            Gym
# 99                      Gay Bar                     Restaurant
# 100              Farmers Market                  Burrito Place
# 101                 Yoga Studio                     Donut Shop
# 102           Convenience Store                 Discount Store
#
#            5th Most Common Venue        6th Most Common Venue  \
# 1                    Yoga Studio                 Dessert Shop
# 2                        Theater                   Restaurant
# 3             Miscellaneous Shop                   Shoe Store
# 4                     Restaurant                    Nightclub
# 6             Dim Sum Restaurant                        Diner
# 7                           Café                      Dog Run
# 8             Athletics & Sports                     Bus Line
# 9                 Cosmetics Shop    Middle Eastern Restaurant
# 13                    Beer Store               Sandwich Place
# 14                      Pharmacy               Cosmetics Shop
# 15            Italian Restaurant               Cosmetics Shop
# 16                   Yoga Studio                      Dog Run
# 17                          Park                  Coffee Shop
# 18                          Bank          Rental Car Location
# 19                       Dog Run             Department Store
# 20                   Cheese Shop               Farmers Market
# 22            Dim Sum Restaurant                        Diner
# 23                          Bank            Electronics Store
# 24                Sandwich Place          Japanese Restaurant
# 25                    Baby Store                   Restaurant
# 26            Athletics & Sports              Thai Restaurant
# 27           Distribution Center                 Dessert Shop
# 28                Ice Cream Shop                Deli / Bodega
# 29                  Burger Joint                  Coffee Shop
# 30                    Steakhouse                          Bar
# 31                          Park         Fast Food Restaurant
# 33                Cosmetics Shop                Women's Store
# 34                           Bar                  Yoga Studio
# 36            Italian Restaurant               Scenic Lookout
# 37                      Wine Bar        Vietnamese Restaurant
# 38                    Hobby Shop                  Yoga Studio
# 39              Doner Restaurant                        Diner
# 41                     Bookstore       Furniture / Home Store
# 42                           Bar           Seafood Restaurant
# 43                 Burrito Place          Japanese Restaurant
# 44                  Soccer Field                         Park
# 46                  Liquor Store                Shopping Mall
# 47                  Liquor Store           Italian Restaurant
# 48           American Restaurant                          Gym
# 50                  Dessert Shop           Dim Sum Restaurant
# 51   Eastern European Restaurant          Dumpling Restaurant
# 53                  Liquor Store                Shopping Mall
# 54                       Brewery    Latin American Restaurant
# 55                           Pub                         Café
# 56                   Yoga Studio                      Dog Run
# 57            Dim Sum Restaurant                        Diner
# 58                    Comic Shop                 Dessert Shop
# 59                          Café             Sushi Restaurant
# 60                  Liquor Store                Shopping Mall
# 63              Doner Restaurant                        Diner
# 64                Discount Store          Distribution Center
# 65                   Yoga Studio                      Dog Run
# 67                         Hotel            Food & Drink Shop
# 69        Furniture / Home Store    Cajun / Creole Restaurant
# 70     Middle Eastern Restaurant           Chinese Restaurant
# 71                        Bakery               Sandwich Place
# 72                          Café             Sushi Restaurant
# 73          Fast Food Restaurant                        Diner
# 74                    Donut Shop                 Liquor Store
# 75                  Dessert Shop  Eastern European Restaurant
# 76                Sandwich Place                Burrito Place
# 78                  Skating Rink            Electronics Store
# 79            Italian Restaurant                  Coffee Shop
# 80                     Bookstore          Japanese Restaurant
# 81            Italian Restaurant                  Yoga Studio
# 82            Italian Restaurant          Fried Chicken Joint
# 84                        Bakery                  Coffee Shop
# 86                   Pizza Place                   Sports Bar
# 87                   Coffee Shop                Boat or Ferry
# 88           Fried Chicken Joint                  Pizza Place
# 89          Fast Food Restaurant               Discount Store
# 90                Sandwich Place                     Pharmacy
# 92                         Hotel                     Beer Bar
# 93                  Skating Rink                         Pool
# 94                  Dessert Shop           Dim Sum Restaurant
# 96                          Park                  Pizza Place
# 97           American Restaurant                        Hotel
# 99              Sushi Restaurant     Mediterranean Restaurant
# 100                  Pizza Place                          Spa
# 101                        Diner               Discount Store
# 102                Burrito Place                 Burger Joint
#
#            7th Most Common Venue      8th Most Common Venue  \
# 1             Dim Sum Restaurant                      Diner
# 2                           Café         Mexican Restaurant
# 3                       Boutique                Event Space
# 4             Mexican Restaurant                  Juice Bar
# 6                 Discount Store        Distribution Center
# 7             Dim Sum Restaurant                      Diner
# 8                       Pharmacy             Breakfast Spot
# 9                        Theater                 Restaurant
# 13            Italian Restaurant         Dim Sum Restaurant
# 14              Doner Restaurant         Dim Sum Restaurant
# 15                      Beer Bar             Clothing Store
# 16                  Dessert Shop         Dim Sum Restaurant
# 17                    Beer Store                Pizza Place
# 18                  Intersection                Yoga Studio
# 19                  Dessert Shop         Dim Sum Restaurant
# 20                        Bakery                 Restaurant
# 22                Discount Store        Distribution Center
# 23                 Shopping Mall                 Restaurant
# 24     Middle Eastern Restaurant         Chinese Restaurant
# 25                   Candy Store                Coffee Shop
# 26                          Bank           Hakka Restaurant
# 27            Dim Sum Restaurant                      Diner
# 28     Middle Eastern Restaurant                 Restaurant
# 29          Fast Food Restaurant                Gas Station
# 30                           Gym                     Bakery
# 31                          Café                        Bar
# 33              Toy / Game Store                       Bank
# 34                         Diner             Discount Store
# 36                    Restaurant                    Brewery
# 37                   Men's Store                Pizza Place
# 38              Doner Restaurant         Dim Sum Restaurant
# 39                Discount Store        Distribution Center
# 41                   Yoga Studio                       Café
# 42            Italian Restaurant                  Gastropub
# 43            Italian Restaurant               Intersection
# 44                   Bus Station               Intersection
# 46                          Park                Coffee Shop
# 47                 Burrito Place                 Restaurant
# 48                     Gastropub              Deli / Bodega
# 50                         Diner             Discount Store
# 51                     Drugstore                 Donut Shop
# 53                          Park                Coffee Shop
# 54                           Bar           Stationery Store
# 55              Sushi Restaurant             Ice Cream Shop
# 56            Dim Sum Restaurant                      Diner
# 57                Discount Store        Distribution Center
# 58          Colombian Restaurant        Empanada Restaurant
# 59                Discount Store             Sandwich Place
# 60                          Park                Coffee Shop
# 63                Discount Store        Distribution Center
# 64                       Dog Run           Doner Restaurant
# 65            Dim Sum Restaurant                      Diner
# 67              Department Store             Sandwich Place
# 69                        Bakery                      Diner
# 70                   Yoga Studio           Department Store
# 71              Doner Restaurant                      Diner
# 72                Discount Store             Sandwich Place
# 73                  Dessert Shop         Mexican Restaurant
# 74                  Burger Joint          Indian Restaurant
# 75                   Coffee Shop                  Bookstore
# 76      Mediterranean Restaurant  Middle Eastern Restaurant
# 78   Eastern European Restaurant        Empanada Restaurant
# 79                          Café           Sushi Restaurant
# 80            Italian Restaurant                Yoga Studio
# 81             French Restaurant                        Pub
# 82               Thai Restaurant         Chinese Restaurant
# 84            Mexican Restaurant        Dumpling Restaurant
# 86                    Restaurant           Sushi Restaurant
# 87                      Boutique            Harbor / Marina
# 88                        Bakery                  Pet Store
# 89                      Pharmacy                Pizza Place
# 90                          Bank                 Nail Salon
# 92           Japanese Restaurant                       Park
# 93                           Pub                Coffee Shop
# 94                         Diner             Discount Store
# 96                           Pub                       Café
# 97                    Steakhouse           Asian Restaurant
# 99                         Hotel               Dance Studio
# 100                       Garden              Garden Center
# 101          Distribution Center                    Dog Run
# 102               Sandwich Place       Fast Food Restaurant
#
#          9th Most Common Venue       10th Most Common Venue
# 1               Discount Store          Distribution Center
# 2                  Event Space               Chocolate Shop
# 3        Vietnamese Restaurant                    Gift Shop
# 4           Italian Restaurant                   Hobby Shop
# 6                      Dog Run                   Donut Shop
# 7               Discount Store          Distribution Center
# 8         Fast Food Restaurant         Gym / Fitness Center
# 9             Ramen Restaurant               Lingerie Store
# 13                        Café                 Concert Hall
# 14                       Diner               Discount Store
# 15                      Bakery                        Diner
# 16                       Diner               Discount Store
# 17              Cosmetics Shop                      Dog Run
# 18              Discount Store           Dim Sum Restaurant
# 19                       Diner               Discount Store
# 20                        Café                    Irish Pub
# 22                     Dog Run             Doner Restaurant
# 23                   Juice Bar               Sandwich Place
# 24                 Salad Place         Gym / Fitness Center
# 25                 Gas Station                        Diner
# 26                   Drugstore                   Donut Shop
# 27              Discount Store                  Yoga Studio
# 28                 Pizza Place          Fried Chicken Joint
# 29               Grocery Store                 Liquor Store
# 30          Seafood Restaurant                  Pizza Place
# 31                 Supermarket                         Bank
# 33           Convenience Store                    Juice Bar
# 34         Distribution Center                      Dog Run
# 36         Sporting Goods Shop          Fried Chicken Joint
# 37                        Café                  Yoga Studio
# 38                       Diner          Distribution Center
# 39                     Dog Run                   Donut Shop
# 41        Caribbean Restaurant                        Diner
# 42         Japanese Restaurant          American Restaurant
# 43                  Restaurant                      Stadium
# 44         Distribution Center                        Diner
# 46                       Hotel               Baseball Field
# 47        Fast Food Restaurant                   Steakhouse
# 48          Seafood Restaurant           Italian Restaurant
# 50         Distribution Center                   Donut Shop
# 51            Doner Restaurant                Deli / Bodega
# 53                       Hotel               Baseball Field
# 54                 Fish Market               Ice Cream Shop
# 55           Indian Restaurant         Fast Food Restaurant
# 56         Distribution Center                   Donut Shop
# 57                     Dog Run             Doner Restaurant
# 58           Electronics Store  Eastern European Restaurant
# 59                  Restaurant          Japanese Restaurant
# 60                       Hotel               Baseball Field
# 63                     Dog Run                    Drugstore
# 64                 Yoga Studio             Department Store
# 65              Discount Store          Distribution Center
# 67         Distribution Center           Dim Sum Restaurant
# 69                   Speakeasy          Fried Chicken Joint
# 70                Dessert Shop           Dim Sum Restaurant
# 71              Discount Store          Distribution Center
# 72                  Restaurant          Japanese Restaurant
# 73                        Park           Chinese Restaurant
# 74                         Pub    Middle Eastern Restaurant
# 75                         Bar                Movie Theater
# 76         Fried Chicken Joint                          Gym
# 78         Dumpling Restaurant                 Dessert Shop
# 79                    Pharmacy           Seafood Restaurant
# 80                 Flower Shop                          Pub
# 81   Latin American Restaurant                    Juice Bar
# 82                        Bank         Fast Food Restaurant
# 84                 Pizza Place                         Park
# 86         American Restaurant          Fried Chicken Joint
# 87                         Bar                 Airport Gate
# 88                    Pharmacy         Fast Food Restaurant
# 89         Japanese Restaurant           Dim Sum Restaurant
# 90              Breakfast Spot                Grocery Store
# 92                      Bakery                  Cheese Shop
# 93                  Comic Shop                 Dance Studio
# 94         Distribution Center             Doner Restaurant
# 96                     Butcher                  Snack Place
# 97         Japanese Restaurant           Seafood Restaurant
# 99                        Café                    Gastropub
# 100       Fast Food Restaurant                         Park
# 101           Doner Restaurant                    Drugstore
# 102            Supplement Shop                   Kids Store

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 11  Etobicoke               4             Gift Shop           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11      Doner Restaurant          Dessert Shop    Dim Sum Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 11                 Diner        Discount Store   Distribution Center
#
#    9th Most Common Venue 10th Most Common Venue
# 11               Dog Run             Donut Shop
